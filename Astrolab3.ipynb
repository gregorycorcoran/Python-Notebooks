# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 22})
plt.rcParams["figure.figsize"] = (15,10)

# %%
BV=np.array([0.8,-0.11,0.349,0.549,1.009,0.983,0.36,0.987,0.643,0.02,0.47,1.175,-0.09,1.228,0.592,1.153,1.701,-0.07,0.565,0.121,0.802,1.108,0.178,0.13])
V=np.array([12.514,4.31,8.6,9.7,12.047,14.369,8.11,12.021,10.517,6.8,9.46,12.607,2.87,7.72,16.43,8.8,6.461,5.451,10.02,6.949,11.345,15.734,9.165,7.421])
MSBV=np.array([0.8,-0.11,0.349,0.549,1.009,0.983,0.36,0.987,0.643,0.02,0.47,1.175,-0.09,-0.07,0.565,0.121,0.802,1.108,0.178,0.13])
MSV=np.array([12.514,4.31,8.6,9.7,12.047,14.369,8.11,12.021,10.517,6.8,9.46,12.607,2.87,5.451,10.02,6.949,11.345,15.734,9.165,7.421])
BVa=np.array([-0.35,-0.31,-0.16,0,0.13,0.27,0.42,0.58,0.7,0.89,1.18,1.45,1.63,1.8])
Va=np.array([-5.8,-4.1,-1.1,-0.7,2,2.6,3.4,4.4,5.1,5.9,7.3,9,11.8,16])

# %%
plt.scatter(MSBV,MSV-5.5)
fitm=np.polyfit(MSBV,MSV,3)
#print(fitm)
def fit1(x):
    return (4.963221*x**3)-(9.9617*x**2)+(12.145*x)+5.72
x1=np.arange(-0.2,1.25,0.01)
fita=np.polyfit(BVa,Va,3)
print(fita)
def fita(x):
    return 5.317*x**3-11.4*x**2+11.72*x+0.3554
x2=np.arange(-0.35,1.9,0.01)
plt.plot(x2,fita(x2))
plt.plot(x1,fit1(x1)-5.5)
plt.plot(x1,fit1(x1)-5.3)
plt.plot(x1,fit1(x1)-5.7)
plt.scatter(BVa,Va)
plt.grid(True)
plt.ylim(17,-6)
# Out:
# [  5.31707464 -11.39927592  11.72033868   0.35540013]
# (17.0, -6.0)

# %%
plt.scatter(BV,V)
plt.scatter(BVa,Va)
plt.ylim(17,-6)
plt.grid(True)
plt.legend(['Obtained Data','Model Main Sequence'])
plt.xlabel('B-V')
plt.ylabel('Magnitude')
# Out:
# Text(0, 0.5, 'Magnitude')

# %%
plt.scatter(BVa,Va+5.3)
plt.scatter(BVa,Va+5.7)
plt.scatter(BVa,Va+6.1)
plt.grid(True)
plt.ylim(17,-6)
plt.scatter(MSBV,MSV,c='black',marker='x')
plt.legend(['Offset=5.3','Offset=5.7','Offset=6.1','Obtained Data'])
plt.xlabel('B-V')
plt.ylabel('Visual Magnitude')
# Out:
# Text(0, 0.5, 'Visual Magnitude')
