# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt 
from shapely.geometry import Point
from geopandas.tools import sjoin
import plotly.express as px
import xarray as xr
import cartopy.crs as ccrs

# %%
data=xr.open_dataset("C:/Users/gjc10/Downloads/HadEX3_Rx1day_ANN.nc")
data.Rx1day[0]
# Out:
# <xarray.DataArray 'Rx1day' (latitude: 144, longitude: 192)>
# [27648 values with dtype=float32]
# Coordinates:
#     time       datetime64[ns] 1901-07-01
#   * longitude  (longitude) float64 0.9375 2.812 4.688 ... 355.3 357.2 359.1
#   * latitude   (latitude) float64 -89.38 -88.12 -86.88 ... 86.88 88.12 89.38
# Attributes:
#     standard_name:  Rx1day
#     units:          mm
#     definition:     Maximum 1-day precipitation total
#     long_name:      Max 1-day PR
#     team:           Expert Team on Climate Change Detection and Indices (ETCCDI)

# %%
plt.figure(figsize=(14, 6))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_global()
data.Rx1day[90].plot.pcolormesh()
ax.coastlines()
