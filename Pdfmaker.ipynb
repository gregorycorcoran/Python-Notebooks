# %%
import pypdf
from glob import glob

# %%
pdflist=glob('C:/Users/gjc10/Desktop/NGSF/2023Files/*.pdf')
print(pdflist)
# Out:
# ['C:/Users/gjc10/Desktop/NGSF/2023Files\\2023abq_0.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023abq_1.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023abq_2.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023abq_3.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023abq_4.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023acr_0.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023acr_1.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023acr_2.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023acr_3.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023acr_4.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023aew_0.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023aew_1.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023aew_2.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023aew_3.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023aew_4.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023apl_0.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023apl_1.pdf', 'C:/Users/gjc10/Desktop/NGSF/2023Files\\2023a
# ...

# %%
merger = pypdf.PdfWriter()

for pdf in pdflist:
    merger.append(pdf)

merger.write("C:/Users/gjc10/Desktop/NGSF/2023Files/merged-pdf.pdf")
merger.close()
